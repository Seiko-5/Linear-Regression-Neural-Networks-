# %% [markdown]
# <a href="https://colab.research.google.com/github/Seiko-5/Linear-Regression-Neural-Networks-/blob/main/_01_Linear_Regression_%26_Neural_Networks_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. Loading Data Set

# %%
# Data Manipulation libraries

import pandas as pd
import numpy as np

# %% [markdown]
# Most common libraries are pre-installed in Google Colab environment. However, sometimes you would need libraries that are not installed. You can use "!pip install (libname)" to install such libraries.

# %%
# !pip install scipy

# %%
# Load the data set as df_boston

df_boston = pd.read_csv('tp3_boston_data.csv')

# %% [markdown]
# # 02. Inspecting Data Set

# %%
# We print the value of the boston_dataset to understand what it contains. print(boston_dataset.keys()) gives
 print(df_boston.keys())
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# **Description of the dataset:**
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per 10,000 dollars
# PTRATIO - pupil-teacher ratio by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's (target)

# %%
# Data set's information --(looking for N/A values,Range, Columns, Data type)
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  medv     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
## Inspect the data set's 1st rows
df_boston.head()
# Out:
#       crim    zn  indus  chas    nox  ...  rad  tax  ptratio  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...    1  296     15.3   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...    2  242     17.8   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...    2  242     17.8   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...    3  222     18.7   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...    3  222     18.7   5.33  36.2
#
# [5 rows x 13 columns]

# %%
# Inspect the data set's last rows
df_boston.tail()
# Out:
#         crim   zn  indus  chas    nox  ...  rad  tax  ptratio  lstat  medv
# 501  0.06263  0.0  11.93     0  0.573  ...    1  273     21.0   9.67  22.4
# 502  0.04527  0.0  11.93     0  0.573  ...    1  273     21.0   9.08  20.6
# 503  0.06076  0.0  11.93     0  0.573  ...    1  273     21.0   5.64  23.9
# 504  0.10959  0.0  11.93     0  0.573  ...    1  273     21.0   6.48  22.0
# 505  0.04741  0.0  11.93     0  0.573  ...    1  273     21.0   7.88  11.9
#
# [5 rows x 13 columns]

# %%
# Discriptive statistics of the data set
print(df_boston.describe())
# Out:
#              crim          zn       indus  ...     ptratio       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...   18.455534   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...    2.164946    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...   12.600000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...   17.400000    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...   19.050000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...   20.200000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...   22.000000   37.970000   50.000000
#
# [8 rows x 13 columns]

# %%
"""
    object − Summarizes String columns
    number − Summarizes Numeric columns
    all − Summarizes all columns together (Should not pass it as a list value)
"""
print (df_boston. describe(include='all'))
# Out:
#              crim          zn       indus  ...     ptratio       lstat        medv
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...   18.455534   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...    2.164946    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...   12.600000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...   17.400000    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...   19.050000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...   20.200000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...   22.000000   37.970000   50.000000
#
# [8 rows x 13 columns]

# %%
# Multiple statistics for selected columns using .agg funtion
df_boston[['age','crim']].agg(['min','mean','max','median'])
# Out:
#                age       crim
# min       2.900000   0.006320
# mean     68.574901   3.613524
# max     100.000000  88.976200
# median   77.500000   0.256510

# %% [markdown]
# **Basic Descriptive Statistics**
#
# *  describe -	Basic statistics (count, mean, std, min, quantiles, max)
# *  min, max -		Minimum and maximum values
# *  mean, median, mode -		Arithmetic average, median and mode
# *  var, std -		Variance and standard deviation
# *  sem	 -	Standard error of mean
# *  skew	 -	Sample skewness
# *  kurt -		kurtosis

# %%
# Returns a random sample of the data frame -- 10 is the sample size
print(df_boston.sample(10))
# Out:
#          crim    zn  indus  chas    nox  ...  rad  tax  ptratio  lstat  medv
# 118   0.13058   0.0  10.01     0  0.547  ...    6  432     17.8  15.37  20.4
# 45    0.17142   0.0   6.91     0  0.448  ...    3  233     17.9  10.21  19.3
# 48    0.25387   0.0   6.91     0  0.448  ...    3  233     17.9  30.81  14.4
# 444  12.80230   0.0  18.10     0  0.740  ...   24  666     20.2  23.79  10.8
# 81    0.04462  25.0   4.86     0  0.426  ...    4  281     19.0   7.22  23.9
# 483   2.81838   0.0  18.10     0  0.532  ...   24  666     20.2  10.42  21.8
# 96    0.11504   0.0   2.89     0  0.445  ...    2  276     18.0  11.34  21.4
# 14    0.63796   0.0   8.14     0  0.538  ...    4  307     21.0  10.26  18.2
# 222   0.62356   0.0   6.20     1  0.507  ...    8  307     17.4   9.93  27.5
# 60    0.14932  25.0   5.13     0  0.453  ...    8  284     19.7  13.15  18.7
#
# [10 rows x 13 columns]

# %% [markdown]
# # 03. Handling Missing Values

# %% [markdown]
# df.method()
#
# *  dropna() - Drop missing observations
# *  dropna(how='all')- 	Drop observations where all cells is NA
# *  dropna(axis=1, how='all')- 	Drop column if all the values are missing
# *  dropna(thresh = 5)- 	Drop rows that contain less than 5 non-missing values
# *  fillna(0)	- Replace missing values with zeros
# *  isnull()	- returns True if the value is missing
# *  notnull()	- Returns True for non-missing values

# %%
# Replacing missing value with mean
df_boston['age'].fillna(df_boston['age'].mean(),inplace= True) #No missing values are in the initial data set

# %%
# Count all missing values in a DataFrame (both columns & Rows)
df_boston.isnull().sum().sum()
# Out:
# 0

# %%
# Count total missing values at each column in DataFrame
df_boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# lstat      0
# medv       0
# dtype: int64

# %%
# Count total missing values at each row in DataFrame
for i in range(len(df_boston.index)) :
    print("Nan in row ", i , " : " ,  df_boston.iloc[i].isnull().sum())
# Out:
# Nan in row  0  :  0
# Nan in row  1  :  0
# Nan in row  2  :  0
# Nan in row  3  :  0
# Nan in row  4  :  0
# Nan in row  5  :  0
# Nan in row  6  :  0
# Nan in row  7  :  0
# Nan in row  8  :  0
# Nan in row  9  :  0
# Nan in row  10  :  0
# Nan in row  11  :  0
# Nan in row  12  :  0
# Nan in row  13  :  0
# Nan in row  14  :  0
# Nan in row  15  :  0
# Nan in row  16  :  0
# Nan in row  17  :  0
# Nan in row  18  :  0
# Nan in row  19  :  0
# Nan in row  20  :  0
# Nan in row  21  :  0
# Nan in row  22  :  0
# Nan in row  23  :  0
# Nan in row  24  :  0
# Nan in row  25  :  0
# Nan in row  26  :  0
# Nan in row  27  :  0
# Nan in row  28  :  0
# Nan in row  29  :  0
# Nan in row  30  :  0
# Nan in row  31  :  0
# Nan in row  32  :  0
# Nan in row  33  :  0
# Nan in row  34  :  0
# Nan in row  35  :  0
# Nan in row  36  :  0
# Nan in row  37  :  0
# Nan in row  38  :  0
# Nan in row  39  :  0
# Nan in row  40  :  0
# Nan in row  41  :  0
# Nan in row  42  :  0
# ...

# %%
# Select the rows that have at least one missing value  Note- This data set is 0 N/A values so only the heddings are comming.
df_boston[df_boston.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, lstat, medv]
# Index: []

# %% [markdown]
# # 04. Visualization & Plotting

# %%
# Visualization libraries

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

# we use inline comand here. Insted of plt.show() we can direcly run the plot. (In pycham, spider this comad will not work)

# %%
# Let’s first plot the distribution of the target variable. (In this case target variabale is MEDV)

# We will use the distplot function from the seaborn library.

#Histogram of MEDV by binning to 30 bins

sns.distplot(df_boston['medv'], bins=(30), color="red", axlabel="MEDV")  
plt.show()

""" More about seaborn
https://seaborn.pydata.org/generated/seaborn.distplot.html """
# Out:
# ' More about seaborn\nhttps://seaborn.pydata.org/generated/seaborn.distplot.html '

# %%
# Create box plots
df_boston.boxplot()

# %%
# create a correlation matrix that measures the linear relationships between the variables. 

# The correlation matrix can be formed by using the corr function from the pandas dataframe library. 

# We will use the heatmap function from the seaborn library to plot the correlation matrix.

correlation_matrix = df_boston.corr().round(1)
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# Observations:
#
# *  To fit a linear regression model, we select those features which have a high correlation with our target variable MEDV. By looking at the correlation matrix we can see that RM has a strong positive correlation with MEDV (0.7) where as LSTAT has a high negative correlation with MEDV(-0.74).
#
# *  An important point in selecting features for a linear regression model is to check for multi-co-linearity. The features RAD, TAX have a correlation of 0.91. These feature pairs are strongly correlated to each other. We should not select both these features together for training the model. Same goes for the features DIS and AGE which have a correlation of -0.75.

# %%
# Based on the above observations we will RM and LSTAT as our features. 

#Using a scatter plot let’s see how these features vary with MEDV.

features = ['lstat', 'rm']
target = df_boston['medv']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    x = df_boston[col]
    y = target
    plt.scatter(x, y, marker='*',color="green")
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')
  

plt.show()

# %% [markdown]
# # 05. Split the Data - Original Data Set without Pre-Processing and Feature Engineering

# %%
# Predictive Analytics models
import sklearn
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection  import train_test_split 

## from sklearn.model_selection  import train_test_split  is same for train val split

# %%
# split the dataset into predictors (df_x) and target variable (df_y)

df_x = df_boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat']]
df_y = df_boston[['medv']]

# %%
"""
0.33 is the 1/3 of the data set.

Random_state simply sets a seed to the random generator, so that your train-val splits are always deterministic.
If you don't set a seed, it is different each time.It doesn't matter if the random_state is 0 or 1 or any other integer.
What matters is that it should be set the same value, if you want to validate your processing over multiple runs of the code
"""

X_train, X_val, Y_train, Y_val = train_test_split(df_x, df_y, test_size = 0.33, random_state = 5)

# %% [markdown]
# # 06. Linear Regression Model

# %% [markdown]
# ##Linear Regression Modeling without Scaling/Standardization Data

# %% [markdown]
# Method API: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,Y_train)
Y_predict = reg.predict(X_val)

# %%
plt.scatter(Y_val, Y_predict, marker='*',color="green")
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value mannualy by using equation

error = np.sqrt(np.mean((Y_predict - Y_val)**2))
print('Root Mean Squared Error: ' + str(error))
# Out:
# Root Mean Squared Error: medv    5.309472
# dtype: float64

# %%
# Calculate RMSE value using numpy funtion

error_1 = np.sqrt(mean_squared_error(Y_val, Y_predict)) # From sklearn.metrics, mean_squared_error import
print('Root Mean Squared Error: ' + str(error_1))
# Out:
# Root Mean Squared Error: 5.309471828719486

# %% [markdown]
# ## Linear Regression Modeling with Scaling/Standardization Data

# %% [markdown]
# Analysing the Dispertion of the Variables (Features)

# %%
# Box plot analysis
df_x.boxplot()

# %% [markdown]
# Data Dispersion is Extremely Different Among Different Features. Thus, Scaling/Standardization is Required.

# %% [markdown]
# ## Data Standardization

# %%
# Use standard scaling from sklearn library
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_x)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
df_x_scaled = scaler.transform(df_x)
df_x_scaled = pd.DataFrame(df_x_scaled, columns=df_x.columns)

# %%
# Show boxplot for scaled predictors
df_x_scaled.boxplot()

# %% [markdown]
# ## Regression Modeling

# %%
# Run the predictive model to see whether accuracy has improved.
X_train, X_val, Y_train, Y_val = train_test_split(df_x_scaled, df_y, test_size = 0.33, random_state = 5)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,Y_train)
Y_predict1 = reg.predict(X_val)

# %%
plt.scatter(Y_val, Y_predict1,marker='*',color="green")
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value using numpy funtion

error_2 = np.sqrt(mean_squared_error(Y_val, Y_predict))
print('Root Mean Squared Error: ' + str(error_2))
# Out:
# Root Mean Squared Error: 5.309471828719491

# %% [markdown]
# Attempt 1 (original data) RMSE: 5.309471828719486
#
# Attempt 2 (with scaling) RMSE: 5.309471828719491
#
# We do not see any difference in scaling in this case.

# %% [markdown]
# ### Correlation Analaysis

# %%
# Correlation plot (method01)

# Correlation plot
  corr = df_x_scaled.corr()
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
  fig.colorbar(cax)
  ticks = np.arange(0,len(df_x_scaled.columns),1)
  ax.set_xticks(ticks)
  plt.xticks(rotation=90)
  ax.set_yticks(ticks)
  ax.set_xticklabels(df_x_scaled.columns)
  ax.set_yticklabels(df_x_scaled.columns)
  plt.show()

# %%
# Correlation plot (method02)

correlation_matrix = df_x.corr().round(1) # round is for rounding value
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # 07. Neural Networks

# %% [markdown]
# Model an Advanced Predictive Model using Standard Neural Network.

# %%
from sklearn.neural_network import MLPRegressor 
# Multi layer perceptron regressor model.Regressor is for regration model.
# Furthermore, NN for clasification we have to use MLPClassifier (Passenger will servive or not).

# %% [markdown]
# Method API: https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html

# %%
mlp = MLPRegressor(hidden_layer_sizes=(60), max_iter=1000)

# Hidden_layer_sizes is the number of nurons in the hidden layer
# max_iter is describes the number of times a batch of data passed through the algorithm. 
# In the case of neural networks, that means the forward pass and backward pass

# %%
mlp.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=60, learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='adam',
# ...

# %%
Y_predict2 = mlp.predict(X_val)

# %%
#Plot the predicted values

plt.scatter(Y_val, Y_predict2, marker='*',color="green",)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value using numpy funtion
error_3 = np.sqrt(mean_squared_error(Y_val, Y_predict))
print('Root Mean Squared Error: ' + str(error_3))
# Out:
# Root Mean Squared Error: 3.664004206535395

# %% [markdown]
# # 08. Comparison of the Root Mean Squared Error Values

# %%
models = ['LR1', 'LR2', 'ANN']
y_pos = np.arange(len(models))
performance = [error_1, error_2, error_3]
 
plt.bar(y_pos, performance, align='center', alpha=0.5,color="green")
plt.xticks(y_pos, models)
plt.ylabel('RMSE (Error)')
plt.title('Evaluation for house price prediction')
 
plt.show()

# %% [markdown]
# # 09. Data Set with Pre-Processing and Feature Engineering

# %% [markdown]
#  We can improve the accuracy by focusing on the data pre-processing and feature engineering. One approach is to transform skewed data.
#
# Visualize the skewness of the dataset, and transform the data accordingly (e.g., log, reciprocal (1/x) or square transformation.)
#
# An example can be found from this medium article on Transforming Skewed Data for Machine Learning.

# %%
# Visualize the data discribtion using pandas dataframe:
df_boston.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f133959c470>,
# ...
#       dtype=object)

# %% [markdown]
# ## Calculate Skewness for all the Continous Variables.

# %%
# Determine index for continouse variables
cts_vars = df_boston.dtypes[df_boston.dtypes != 'object'].index

# Calculate the skewness and then sort
skew_vars = df_boston[cts_vars].skew().sort_values(ascending=False)
print(skew_vars)
# Out:
# crim       5.223149
# chas       3.405904
# zn         2.225666
# medv       1.108098
# dis        1.011781
# rad        1.004815
# lstat      0.906460
# nox        0.729308
# tax        0.669956
# rm         0.403612
# indus      0.295022
# age       -0.598963
# ptratio   -0.802325
# dtype: float64

# %% [markdown]
# We can address skewed variables by transforming them (i.e. applying the same function to each value).
#
# Common transformations include square root (sqrt(x)), logarithmic (log(x)), and reciprocal (1/x).

# %% [markdown]
# Ploting Skiwed Variable

# %%
sns.distplot(df_boston['crim'])

# %%
sns.distplot(df_boston['chas'])

# %%
sns.distplot(df_boston['zn'])

# %%
sns.distplot(df_boston['ptratio'])

# %%
sns.distplot(df_boston['age'])

# %%
sns.distplot(df_boston['dis'])

# %%
sns.distplot(df_boston['rad'])

# %% [markdown]
# ## Change the Variable Names to Transformation

# %%
crim_var = df_boston['crim']

# %%
chas_var = df_boston['chas']

# %%
zn_var = df_boston['zn']

# %%
ptratio_var = df_boston['ptratio']

# %%
age_var = df_boston['age']

# %%
dis_var = df_boston['dis']

# %%
rad_var = df_boston['rad']

# %% [markdown]
# ## Square Root Transformation.

# %%
sqrt_crim = crim_var ** (1/2)

# %%
sqrt_chas = chas_var ** (1/2)

# %%
sqrt_zn = zn_var  ** (1/2)

# %%
sqrt_ptratio = ptratio_var  ** (1/2)

# %%
sqrt_age = age_var  ** (1/2)

# %%
sqrt_dis = dis_var  ** (1/2)

# %%
sqrt_rad = rad_var  ** (1/2)

# %% [markdown]
# ### Visualisation of the Squre Root Transformation

# %%
sns.distplot(sqrt_crim)

# %%
sns.distplot(sqrt_chas)

# %%
sns.distplot(sqrt_zn)

# %%
sns.distplot(sqrt_ptratio)

# %%
sns.distplot(sqrt_age)

# %%
sns.distplot(sqrt_dis)

# %%
sns.distplot(sqrt_rad)

# %% [markdown]
# ## Log Transformation

# %%
log_crim = np.log(crim_var)

# %%
log_chas = np.log(chas_var)

# %%
log_zn = np.log(zn_var)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
log_ptratio = np.log(ptratio_var)

# %%
log_age = np.log(age_var)

# %%
log_dis = np.log(dis_var)

# %%
log_rad = np.log(rad_var)

# %% [markdown]
# ### Visualization of the Log Transfomation

# %%
sns.distplot(log_crim)

# %%
sns.distplot(log_chas)

# %%
sns.distplot(log_zn)

# %%
sns.distplot(log_ptratio)

# %%
sns.distplot(log_age)

# %%
sns.distplot(log_dis)

# %%
sns.distplot(log_rad)

# %% [markdown]
# ## Construct the New Variable

# %% [markdown]
# The log transformation seems to have de-skewed.
#
# Therefore, we can construct the new variables.

# %%
df_boston['log_crim'] = log_crim

# %%
df_boston['log_ptratio'] = log_ptratio

# %%
df_boston['log_age'] = log_age

# %%
df_boston['log_dis'] = log_dis

# %%
df_boston['log_rad'] = log_rad

# %% [markdown]
# Important: Once you create the new variable, make sure delete the original variable when using the dataframe as a predictor.

# %%
#Deleting varibales

del df_boston['dis']
del df_boston['rad']
del df_boston['crim']
del df_boston['ptratio']
del df_boston['age']

# %%
# check the varibales

df_boston.keys()
# Out:
# Index(['zn', 'indus', 'chas', 'nox', 'rm', 'tax', 'lstat', 'medv', 'log_crim',
#        'log_ptratio', 'log_age', 'log_dis', 'log_rad'],
#       dtype='object')

# %% [markdown]
# In this we keep both variables to compare the results

# %% [markdown]
# # 10. Split the Data - Pre Processing and Featured Engineering Data

# %%
# Predictive Analytics models
import sklearn
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection  import train_test_split
from sklearn.ensemble import GradientBoostingRegressor

# %%
# split the dataset into predictors (df_x) and target variable (df_y)
# split the dataset into predictors (df_x) and target variable (df_y)
df_x1 = df_boston[['log_crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'log_age', 'log_dis', 'log_rad', 'tax', 'log_ptratio', 'lstat']]
df_y1 = df_boston[['medv']]

# %%
"""
0.33 is the 1/3 of the data set.

Random_state simply sets a seed to the random generator, so that your train-test splits are always deterministic.
If you don't set a seed, it is different each time.It doesn't matter if the random_state is 0 or 1 or any other integer.
What matters is that it should be set the same value, if you want to validate your processing over multiple runs of the code
"""

X1_train, X1_val, Y1_train, Y1_val = train_test_split(df_x1, df_y1, test_size = 0.33, random_state = 5)

# %% [markdown]
# ## *************************************

# %% [markdown]
# # 11. Regression and Nural Network - Pre Processing and Featured Engineering data

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Linear Regression Modeling without Scaling/Standardization Data

# %% [markdown]
# Method API: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
reg = linear_model.LinearRegression()
reg.fit(X1_train,Y1_train)
Y1_predict3 = reg.predict(X1_val)

# %%
plt.scatter(Y1_val, Y1_predict3, marker='*',color="green")
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value using numpy funtion
error_4 = np.sqrt(mean_squared_error(Y1_val, Y1_predict)) # From sklearn.metrics, mean_squared_error import
print('Root Mean Squared Error: ' + str(error_4))
# Out:
# Root Mean Squared Error: 5.0427522751475635

# %% [markdown]
# ### Linear Regression Modeling with Scaling/Standardization Data

# %% [markdown]
# Analysing the Dispertion of the Variables(Features)

# %%
# Box plot analysis
df_x1.boxplot()

# %% [markdown]
# Data dispersion is extremely different among different features. Thus, scaling/standardization is required.

# %% [markdown]
# #### Data Standardization

# %%
# Use standard scaling from sklearn library
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_x1)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
df_x1_scaled = scaler.transform(df_x1)
df_x1_scaled = pd.DataFrame(df_x1_scaled, columns=df_x1.columns)

# %%
# Show boxplot for scaled predictors
df_x1_scaled.boxplot()

# %% [markdown]
# #### Regression Modeling

# %%
# Run the predictive model to see whether accuracy has improved.
X1_train, X1_val, Y1_train, Y1_val = train_test_split(df_x1_scaled, df_y1, test_size = 0.33, random_state = 5)

# %%
reg = linear_model.LinearRegression()
reg.fit(X1_train,Y1_train)
Y1_predict4 = reg.predict(X1_val)

# %%
plt.scatter(Y1_val, Y1_predict4,marker='*',color="green")
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value using numpy funtion
error_5 = np.sqrt(mean_squared_error(Y1_val, Y1_predict))
print('Root Mean Squared Error: ' + str(error_5))
# Out:
# Root Mean Squared Error: 5.0427522751475715

# %% [markdown]
# Attempt 1 (original data) RMSE: 5.0427522751475635
#
# Attempt 2 (with scaling) RMSE: 5.0427522751475715
#
# We do not see any difference in scaling in this case.

# %% [markdown]
# #### Correlation Analaysis

# %%
# Correlation plot
  corr = df_x1_scaled.corr()
  fig = plt.figure()
  ax = fig.add_subplot(111)
  cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
  fig.colorbar(cax)
  ticks = np.arange(0,len(df_x1_scaled.columns),1)
  ax.set_xticks(ticks)
  plt.xticks(rotation=90)
  ax.set_yticks(ticks)
  ax.set_xticklabels(df_x1_scaled.columns)
  ax.set_yticklabels(df_x1_scaled.columns)
  plt.show()

# %%
# Correlation plot (method02)

correlation_matrix = df_x1.corr().round(1) # round is for rounding value
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# ## Advanced Gradient Boosting Regression Model

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr_model = GradientBoostingRegressor()
gbr_model.fit(X1_train,Y1_train)

# Predict
Y1_predict5 = gbr_model.predict(X1_val)

# %%
# Calculate RMSE value using numpy funtion
error_6 = np.sqrt(mean_squared_error(Y1_val_predict1, Y_val))
print('Validation Root Mean Squared Error (Gradient Boosting): ' + str(error_6))
# Out:
# Validation Root Mean Squared Error (Gradient Boosting): 2.927651066630004

# %%
plt.scatter(Y1_val, Y1_predict5,marker='*',color="green")
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# Model an advanced predictive model using standard neural network.

# %%
from sklearn.neural_network import MLPRegressor 
# Multi layer perceptron regressor model.Regressor is for regration model.
# Furthermore, NN for clasification we have to use MLPClassifier (Passenger will servive or not).

# %% [markdown]
# Method API: https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html

# %%
mlp1 = MLPRegressor(hidden_layer_sizes=(60), max_iter=1000)

# Hidden_layer_sizes is the number of nurons in the hidden layer
# max_iter is describes the number of times a batch of data passed through the algorithm. 
# In the case of neural networks, that means the forward pass and backward pass

# %%
mlp1.fit(X1_train, Y1_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=60, learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='adam',
# ...

# %%
Y1_predict6 = mlp1.predict(X1_val)

# %%
#Plot the predicted values

plt.scatter(Y1_val, Y1_predict6, marker='*',color="green",)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %%
# Calculate RMSE value using numpy funtion
error_7 = np.sqrt(mean_squared_error(Y1_val, Y1_predict))
print('Root Mean Squared Error: ' + str(error_7))
# Out:
# Root Mean Squared Error: 5.0427522751475715

# %% [markdown]
# # 12. Comparison of the 7 -- Root Mean Squared Error Values

# %%
models = ['LR1', 'LR2', 'ANN1', 'LR4', 'LR5', 'GBR1', 'ANN2']
y_pos = np.arange(len(models))                             # the x locations for the groups
performance = [error_1, error_2, error_3, error_4, error_5, error_6, error_7]
 
plt.bar(y_pos, performance, align='center', alpha=0.5, color='green', edgecolor = 'red', linewidth =1, width= 0.9)
plt.xticks(y_pos, models)
plt.ylabel('RMSE (Error)')
plt.title('Evaluation for house price prediction')
 
plt.show()

# %% [markdown]
# # 13. Model Evaluation Matrix -- Regression (Continue Value Prediction)

# %% [markdown]
# In here we evaluvate the Nural network using regression evaluvation techniques since we deal with regression data.
#
# "from sklearn.neural_network import MLPRegressor "

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Training accuracy
Y1_train_predict = mlp1.predict(X1_train)
# Validation accuracy
Y1_val_predict = mlp1.predict(X1_val)

# %%
# Error calculation 

# Avarage of the square of the difference between the original values and the predicted values

error_train = np.sqrt(mean_squared_error(Y1_train_predict, Y1_train))
print('Training Root Mean Squared Error: ' + str(error_train))

error_val = np.sqrt(mean_squared_error(Y1_val_predict, Y1_val))
print('Validation Root Mean Squared Error: ' + str(error_val))

# Avarage diferance between the original value and the predicted value

error_train = mean_absolute_error(Y1_train_predict, Y1_train)
print('Training Mean Absolute Error: ' + str(error_train))

error_val = mean_absolute_error(Y1_val_predict, Y1_val)
print('Validation Mean Absolute Error: ' + str(error_val))

# Indication of the goodness of fit of a set of prediction to the actual value.

error_train = r2_score(Y1_train_predict, Y1_train)
print('Training R2 Error: ' + str(error_train))

error_val = r2_score(Y1_val_predict, Y1_val)
print('Validation R2 Error: ' + str(error_val))
# Out:
# Training Root Mean Squared Error: 2.9617666399857794
# Validation Root Mean Squared Error: 3.6287232467816786
# Training Mean Absolute Error: 2.142339370654943
# Validation Mean Absolute Error: 2.458637263934167
# Training R2 Error: 0.8756614772639184
# Validation R2 Error: 0.8203310343523523

# %% [markdown]
# # 14. k-Fold Cross Validation Data Partition

# %% [markdown]
# NURAL NETWORK

# %%
from sklearn.neural_network import MLPRegressor 
# Multi layer perceptron regressor model.Regressor is for regration model.
# Furthermore, NN for clasification we have to use MLPClassifier (Passenger will servive or not).

# %% [markdown]
# Method API: https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html

# %%
mlp2 = MLPRegressor(hidden_layer_sizes=(60), max_iter=1000)

# Hidden_layer_sizes is the number of nurons in the hidden layer
# max_iter is describes the number of times a batch of data passed through the algorithm. 
# In the case of neural networks, that means the forward pass and backward pass

# %%
mlp2.fit(X1_train, Y1_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=60, learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='adam',
# ...

# %%
from sklearn import model_selection

# %%
# Use 10-Fold cross validation with NN 

k = 10 
kfold = model_selection.KFold(n_splits=k, random_state=2)
model = mlp2
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
 print(kfold)
# Out:
# KFold(n_splits=10, random_state=2, shuffle=False)

# %%
scoring = 'r2'
results = model_selection.cross_val_score(model, df_x1, df_y1, cv=kfold, scoring=scoring)
print("Accuracy: {:.2f} ({:.2f})".format(results.mean(), results.std()))

# %%
scoring = 'neg_mean_squared_error'
results = model_selection.cross_val_score(model, df_x1, df_y1, cv=kfold, scoring=scoring)
print("Accuracy: {:.2f} ({:.2f})".format(results.mean(), results.std()))

# %%
scoring = 'neg_mean_absolute_error'
results = model_selection.cross_val_score(model, df_x1, df_y1, cv=kfold, scoring=scoring)
print("Accuracy: {:.2f} ({:.2f})".format(results.mean(), results.std()))

# %% [markdown]
# # 15. XAI (Explainable AI) Techniques & Frameworks

# %% [markdown]
# ## Sensivity Analysis

# %% [markdown]
# Install python library for partial dependence plot toolbox.
# Documentation URL: https://pdpbox.readthedocs.io/en/latest/

# %%
# Install python library for partial dependence plot toolbox
# !pip install pdpbox

# %% [markdown]
# Install python library for SHAP explainer toolbox.
# Documentation URL: https://shap.readthedocs.io/en/latest/

# %%
# Install python library for SHAP explainer toolbox
# !pip install shap

# %% [markdown]
# The following function is created for the convinience to generate PDP plots and ICE plots

# %%
from pdpbox import pdp
def plot_pdp(model, df, feature, cluster_flag=False, nb_clusters=None, lines_flag=False):
    
    # Create the data that we will plot
    pdp_goals = pdp.pdp_isolate(model=model, dataset=df, model_features=df.columns.tolist(), feature=feature)

    # plot it
    pdp.pdp_plot(pdp_goals, feature, cluster=cluster_flag, n_cluster_centers=nb_clusters, plot_lines=lines_flag)

# %% [markdown]
# ### Parcial Dependancy Plot

# %%
from pdpbox import pdp

# %%
#@title Select a predictor to analyse Gradient Boosting Model. { run: "auto" }

selected_predictor = "log_age" #@param ['log_crim','zn', 'indus', 'chas', 'nox', 'rm', 'log_age', 'log_dis', 'log_rad', 'tax', 'log_ptratio', 'lstat']
print('You selected', selected_predictor)
plot_pdp(gbr_model, X1_train, selected_predictor)

# %% [markdown]
# ###ICE Plots

# %%
#@title Select a predictor to analyse Gradient Boosting Model. { run: "auto" }

selected_predictor = "log_age" #@param ['log_crim','zn', 'indus', 'chas', 'nox', 'rm', 'log_age', 'log_dis', 'log_rad', 'tax', 'log_ptratio', 'lstat']
number_clusters = 10 #@param {type:"slider", min:1, max:50, step:1}
print('You selected {} with {} clusters.'.format(selected_predictor, number_clusters))
plot_pdp(gbr_model, X1_train, selected_predictor, cluster_flag=True, nb_clusters=number_clusters, lines_flag=True)

# If you want to take all the data points number_clusters=x1_train.shape[0]

# %% [markdown]
# ## SHAP Explainer

# %%
# import shap library
import shap

# %% [markdown]
# Create a shap explainer from gradient boosting model

# %%
explainer = shap.TreeExplainer(gbr_model)
shap_values = explainer.shap_values(X1_train)

# %% [markdown]
# Explain individual train (or test) data points on their contribution to the outcome.
# The below visualization shows features each contributing to push the model output from the base value (the average model output over the training dataset we passed) to the model output. Features pushing the prediction higher are shown in red, those pushing the prediction lower are in blue

# %%
record_id = 73

print('Actual values:')
print(X1_train.iloc[record_id,:])

# Looks like Google Colab needs shap.initjs() in every cell where there is a visualization.
shap.initjs()

# visualize the first prediction's explanation (use matplotlib=True to avoid Javascript)
shap.force_plot(explainer.expected_value, shap_values[record_id,:], X1_train.iloc[record_id,:])
# Out:
# Actual values:
# log_crim        -2.177804
# zn              30.000000
# indus            4.930000
# chas             0.000000
# nox              0.428000
# rm               6.897000
# log_age          3.994524
# log_dis          1.846263
# log_rad          1.791759
# tax            300.000000
# log_ptratio      2.809403
# lstat           11.380000
# Name: 240, dtype: float64
# ...

# %% [markdown]
# If we take many explanations such as the one shown above, rotate them 90 degrees, and then stack them horizontally, we can see explanations for an entire dataset (in the notebook this plot is interactive):

# %%
# Looks like Google Colab needs shap.initjs() in every cell where there is a visualization.

shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, X1_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# To get an overview of which features are most important for a model we can plot the SHAP values of every feature for every sample. The plot below sorts features by the sum of SHAP value magnitudes over all samples, and uses SHAP values to show the distribution of the impacts each feature has on the model output. The color represents the feature value (red high, blue low). This reveals for example that a high LSTAT (% lower status of the population) lowers the predicted home price.

# %%
# summarize the effects of all the features
shap.initjs()
shap.summary_plot(shap_values, X1_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# We can also just take the mean absolute value of the SHAP values for each feature to get a standard bar plot (produces stacked bars for multi-class outputs).

# %%
shap.initjs()
shap.summary_plot(shap_values, X1_train, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...
